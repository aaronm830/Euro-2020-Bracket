# %% [markdown]
# # Part 2: Scoring
#
# This script is used to score the entries that were processed in EuroBracketETL.ipynb. It also reads information from stored dictionaries that have been uploaded into the repository.

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import glob
import json

# %%
# Reading CSV containing all user predictions processed by Euro Bracket ETL.ipynb
entries = pd.read_csv(r'C:\Users\aaron\Documents\BracketResults.csv')

# Importing and preparing string dictionaries containing results
grouprank = json.load(open(r"C:\Users\aaron\Documents\grouprank.json", "r"))
r16 = json.load(open(r"C:\Users\aaron\Documents\r16.json", "r"))
r16opp = json.load(open(r"C:\Users\aaron\Documents\r16opp.json", "r"))
qf = json.load(open(r"C:\Users\aaron\Documents\qf.json", "r"))
qfopp = json.load(open(r"C:\Users\aaron\Documents\qfopp.json", "r"))
sf = json.load(open(r"C:\Users\aaron\Documents\sf.json", "r"))
sfopp = json.load(open(r"C:\Users\aaron\Documents\sfopp.json", "r"))
f = json.load(open(r"C:\Users\aaron\Documents\f.json", "r"))
fopp = json.load(open(r"C:\Users\aaron\Documents\fopp.json", "r"))
winner = 'Italy'

# %%
# Creates a unique key for each user based on name and Twitter handle to avoid double counting
uniquekey = []
for i in range(0,len(entries)):
    a = entries['name'][i]
    b = entries['Twitter'][i]
    if type(a) != str:
        a = ''
    if type(b) != str:
        b = ''
    uniquekey += [a+' '+b]
    
entries['uniquekey'] = uniquekey

# %%
# Creates a DataFrame containing a list of all countries at Euro 2020
master = pd.DataFrame()
x = list(np.unique(list(entries['country'])))
master['country'] = x

# %%
# Assigns scoring based on matching between master entry and dictionaries imported above
listylist = []
intyint = 0
for i in range(0,len(entries)):
    nation = entries['country'][i]
    in16 = type(entries['r16 opponent'][i]) == str
    inqf = type(entries['qf opponent'][i]) == str
    insf = type(entries['sf opponent'][i]) == str
    inf = type(entries['final opponent'][i]) == str
    if entries['group rank'][i] == grouprank[nation]:
        intyint += 1
    if in16 == r16[nation]:
        intyint += 1
    if entries['r16 opponent'][i] == r16opp[nation]:
        intyint += 1
    if inqf == qf[nation]:
        intyint += 4
    if entries['qf opponent'][i] == qfopp[nation]:
        intyint += 2
    if insf == sf[nation]:
        intyint += 8
    if entries['sf opponent'][i] == sfopp[nation]:
        intyint += 4
    if inf == f[nation]:
        intyint += 16
    if entries['final opponent'][i] == fopp[nation]:
        intyint += 26
    if entries['winner'][i] == winner:
        intyint+= 32
    listylist += [intyint]
    intyint = 0

entries['pointsassigned'] = listylist

# %%
# Formats scores into DataFrame that can be displayed on aaronmoniz.com/football
# and viewed publicly
standings = pd.DataFrame()
namelist = list(np.unique(list(entries['uniquekey'])))
standings['name'] = namelist
cl = list(np.unique(list(entries['country'])))

pts = []
winners = []
for i in namelist:
    approws = entries[entries['uniquekey'] == i]
    pts += [sum(list(approws['pointsassigned']))]
    winners += [np.unique(list(approws['winner']))[0]]

pd.set_option('display.max_rows', None)
standings['winner'] = winners
standings['points'] = pts
standings['% prediction accuracy'] = standings['points']/250*100
standings['% prediction accuracy'] = standings['% prediction accuracy'].round(2)
standings = standings.sort_values(by=['points', 'name'], ascending=[False, True])
standings['rank'] = standings['points'].rank(method='min', ascending=False)
standings = standings.set_index('rank')

# %%
standings.to_csv(r'C:\Users\aaron\Documents\Euro 2020 Bracket Standings.csv')
standings
# Out:
#                                    name       winner  points  \
# rank
# 1.0                    Domenic domvar22        Italy     179
# 2.0               Anirudh imtiredrobbie        Italy     177
# 2.0                Wairi wombatizmailov        Italy     177
# 4.0              Anirudh AnirudhShenoy_      England     151
# 5.0                      Ahmed UTDTruth      England     149
# 6.0                    Omid Alfabigbang      England     145
# 7.0                   Jamie kirkwithane        Italy     117
# 8.0             Rithwik rithwikrajendra        Italy     115
# 9.0                      Anant anantm14        Italy     113
# 9.0               Fabiola fabiola_cejku        Italy     113
# 9.0                   Rahul RahulIyer32        Italy     113
# 12.0                     Nandy nandy_sd        Italy     111
# 13.0                              Gail         Italy     103
# 14.0                      Divine dxvin3        Italy      99
# 15.0         José Fernando barelylegalx      England      95
# 16.0                   Bradley cafcbrad       France      91
# 16.0                        Yuwan U1sid      Belgium      91
# 18.0               Aaron amonizfootball       France      89
# 18.0                   Sam GoalAnalysis        Spain      89
# 20.0                     Max  MTaylor1_      England      87
# 21.0                   Matt trevillion_       France      85
# 21.0                    Mohit mohit2690       France      85
# 23.0                           Kevin S       England      83
# 23.0                     Regan regan_sg      England      83
# 23.0                Vagelis vagelismufc       France      83
# 26.0                  Bryce brycefrentz       France      81
# 26.0                       Harsh ftblhk      England      81
# 26.0                   Joth pompeystats     Portugal      81
# 26.0       Patrick Caskie CaskiePatrick       France      81
# 26.0                Rory  RoryyWatkinss       France      81
# 31.0                     Danny D_C_L_07       France      80
# 31.0               Gunasekaran gunasek_       France      80
# 33.0            Francesco ItalianHawker      England      79
# 33.0                  Josh jammin__josh       France      79
# 33.0                  Rohit Rao rohit4_      England      79
# 33.0                 Taylor trillanocap       France      79
# 37.0                 Aditya futbol_noob       France      77
# 37.0               Elizabeth xlizabetho       France      77
# 37.0        Griffith Nipah breezy_Xcoba      England      77
# 37.0                  Jenish jenish2147      England      77
# 37.0             Keerthi keerthikrlshna       France      77
# 37.0                   Luke GriffinFtbl      England      77
# 37.0               Maram maramperninety      England      77
# 37.0      Matthew Woodburn thedoormattt       France      77
# 37.0                  Neil nragavan3011      Belgium      77
# 37.0                  Oliver oliver_how      England      77
# 37.0               Pierre pierrecheval_       France      77
# 48.0             Mahadevan PendelEffekt       France      75
# 48.0                  RRB downtownfunk0       France      75
# 48.0                  Suwaid doobdibdab      Germany      75
# 51.0              Aniket Aniket_Thorat_      England      73
# 51.0                      Ben BenMUFC__       France      73
# 51.0                 Kamalesh sonus2002      England      73
# 51.0                     Rajat rajats97       France      73
# 51.0                      Shan ksezzxot      Belgium      73
# 56.0                 Adam MillarHistory      England      71
# 56.0            Amalesh  GanchuSankar10      England      71
# 56.0                       Conor conohm       France      71
# 56.0                 Easaa EasaaManiyar      England      71
# 56.0                    Hassan comredhf     Portugal      71
# 128.0                  Amaar Khankilla1       France      49
# 128.0                    Arun ManUtdSZN      Belgium      49
# 128.0                  David ayeayeronu      Germany      49
# 128.0              Jayden PayedItSimple       France      49
# 128.0                   John j0hn_stats       France      49
# 128.0                   Kees HemmenKees  Netherlands      49
# 128.0                 Mason masonmosl3y     Portugal      49
# 128.0                Matt prickwhitman        France      49
# 128.0                   Parth pathaleee       France      49
# 138.0                  Caio CcBatatinha     Portugal      47
# 138.0                Danny calcio_danny       France      47
# 138.0                            Diana       Germany      47
# 138.0               Josh josh_caldwell1      Belgium      47
# 138.0            Kshitij HowAboutThatt_     Portugal      47
# 138.0             Matthew MatthewVenn28      Belgium      47
# 138.0            Michael Moniz MJMoniz1      Belgium      47
# 138.0               Milton MiltonABrown     Portugal      47
# 138.0                Musa Musa_Bavarian      Belgium      47
# 138.0                 S analyticfanatic     Portugal      47
# 138.0   Sihle Mqingwana  sobelweski_mqi      Belgium      47
# 138.0                     Teemu tteemu8      Germany      47
# 150.0  Sreyas Venkataramanan imsreyas_7       France      46
# 151.0              Milhan Kloppista_LFC       France      45
# 151.0              Chris chrisprice0291     Portugal      45
# 151.0                  Ciaran COArsenal       France      45
# 151.0                     Iain RidleyIR       France      45
# 151.0                         RB RB1805      Belgium      45
# 151.0                   Ronan ronanmann     Portugal      45
# 151.0                      Silas nerdn7       France      45
# 151.0                  Yash itsyashdani       France      45
# 159.0       Brian Abutti Not on Twitter       France      43
# 159.0          Joe Lyons JoeLyonsJourno       France      43
# 159.0        Lee Chandler lee_chandler_       France      43
# 159.0                    Mustafa MKFtbl     Portugal      43
# 159.0                     Theo scfctheo       France      43
# 159.0                 Tiago TiagoDCJPII        Spain      43
# 165.0                Gary Kirk GKBoston     Portugal      41
# 165.0                  Joel joelhmallen     Portugal      41
# 167.0                apermadi ariothole      Germany      40
# 168.0                    Elias spagyama      Germany      39
# 168.0                    Jack BrockyJay       France      39
# 170.0                       doxaj d7xaj     Portugal      37
# 171.0                Karan Karan_Mathew     Portugal      35
# 171.0                 Sumukh utdsumukh7      Belgium      35
# 171.0                 Yatin yatin_kapur       France      35
#
#        % prediction accuracy
# rank
# 1.0                     71.6
# 2.0                     70.8
# 2.0                     70.8
# 4.0                     60.4
# 5.0                     59.6
# 6.0                     58.0
# 7.0                     46.8
# 8.0                     46.0
# 9.0                     45.2
# 9.0                     45.2
# 9.0                     45.2
# 12.0                    44.4
# 13.0                    41.2
# 14.0                    39.6
# 15.0                    38.0
# 16.0                    36.4
# 16.0                    36.4
# 18.0                    35.6
# 18.0                    35.6
# 20.0                    34.8
# 21.0                    34.0
# 21.0                    34.0
# 23.0                    33.2
# 23.0                    33.2
# 23.0                    33.2
# 26.0                    32.4
# 26.0                    32.4
# 26.0                    32.4
# 26.0                    32.4
# 26.0                    32.4
# 31.0                    32.0
# 31.0                    32.0
# 33.0                    31.6
# 33.0                    31.6
# 33.0                    31.6
# 33.0                    31.6
# 37.0                    30.8
